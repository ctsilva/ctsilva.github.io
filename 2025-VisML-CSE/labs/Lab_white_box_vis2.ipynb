# %% [markdown]
# # Practice 2: Tree-based model for classification

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# The dataset we are using in this lab comes from FICO xAI challenge: https://community.fico.com/s/explainable-machine-learning-challenge
#
# Download the cleaned fico dataset here: https://drive.google.com/file/d/186LjbAZoMat91ByH7aJGJ8PnfO2LqKlu/view?usp=sharing
#
# And put it on your Google drive.

# %%
df = pd.read_csv(filepath_or_buffer="/content/drive/MyDrive/Colab Notebooks/fico/cleaned_fico_data.csv",)
df
# Out:
#       Outcome  ...  % Trades w/ Balance
# 0           0  ...                   69
# 1           0  ...                    0
# 2           0  ...                   86
# 3           0  ...                   91
# 4           0  ...                   80
# ...       ...  ...                  ...
# 9866        1  ...                  100
# 9867        0  ...                   80
# 9868        0  ...                   56
# 9869        0  ...                   38
# 9870        0  ...                  100
#
# [9871 rows x 24 columns]

# %%
X = df.drop(columns=['Outcome']).values
y = df['Outcome'].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
'''train a decision tree model'''
from sklearn import tree

clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

# %%
'''report the training accuracy'''
clf.score(X_train, y_train)
# Out:
# 1.0

# %%
'''report the testing accuracy'''
clf.score(X_test, y_test)
# Out:
# 0.625537139349294

# %%
'''feature importance'''
clf.feature_importances_
# Out:
# array([0.25629137, 0.07577627, 0.04073107, 0.05904387, 0.04313494,
#        0.0083481 , 0.00425498, 0.03332086, 0.02973802, 0.00711022,
#        0.01093768, 0.04831472, 0.02338126, 0.05863644, 0.03001456,
#        0.01823076, 0.01472734, 0.06467421, 0.05866102, 0.03533788,
#        0.01554473, 0.01877755, 0.04501215])

# %%
'''visualize the tree'''
import graphviz

target_names = ['not default', 'default']
dot_data = tree.export_graphviz(clf, out_file=None,
                                feature_names=df.columns[1:],
                                class_names=target_names,
                                filled=True, rounded=True,
                                special_characters=True)
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# A really large tree!!!
#
# Overfiting!!
#
# Check the parameters you can change: https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html#sklearn.tree.DecisionTreeClassifier

# %%
'''
  Change parameters to avoid overfitting.
'''

clf = tree.DecisionTreeClassifier(min_samples_split=50, max_depth=5)
clf = clf.fit(X_train, y_train)

# %%
clf.score(X_test, y_test)
# Out:
# 0.6961325966850829

# %% [markdown]
# Can you try to change some parameters and reach a higher accuracy?
